# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL da primeira página
url = 'https://www.vivareal.com.br/venda/sp/campinas/apartamento_residencial/'

# Input do número total de páginas
num_paginas = int(input("Digite o número total de páginas: "))

# Lista vazia para armazenar os dados dos anúncios
data = []

# Loop pelas páginas para extrair as informações dos anúncios
for i in range(1, num_paginas + 1):
    # URL da página atual
    url_atual = url + f'?pagina={i}'

    # Realiza a requisição HTTP
    response = requests.get(url_atual)

    # Verifica se a requisição foi bem sucedida
    if response.status_code == 200:
        # Cria o objeto BeautifulSoup para fazer o parsing do HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # Busca pelos anúncios presentes na página
        anuncios = soup.find_all('article', {'class': 'property-card__container'})

        # Loop pelos anúncios para extrair as informações desejadas
        for anuncio in anuncios:
            titulo = anuncio.find('span', {'class': 'property-card__title'}).text.strip()
            endereco = anuncio.find('span', {'class': 'property-card__address'}).text.strip()
            area = anuncio.find('li', {'class': 'property-card__detail-area'}).text.strip()
            quartos = anuncio.find('li', {'class': 'property-card__detail-room'}).text.strip()
            banheiros = anuncio.find('li', {'class': 'property-card__detail-bathroom'}).text.strip()
            garagens = anuncio.find('li', {'class': 'property-card__detail-garage'}).text.strip()
            preco = anuncio.find('div', {'class': 'property-card__price'}).text.strip()
            condominio_tag = anuncio.find('div', {'class': 'property-card__price-details--condo'})

            if condominio_tag:
                condominio_tag = condominio_tag.find('strong', {'class': 'js-condo-price'})
                condominio = condominio_tag.text.strip() if condominio_tag else None
            else:
                condominio = None
                
            # Adiciona os dados à lista
            data.append([titulo, endereco, area, quartos, banheiros, garagens, preco, condominio])
    else:
        print(f'Não foi possível obter os dados da página {i}.')

# Cria um dataframe com os dados
df = pd.DataFrame(data, columns=['Título', 'Endereço', 'Área', 'Quartos', 'Banheiros', 'Garagens', 'Preço', 'Condomínio'])

# Exibe o dataframe
display(df)
# Out:
# Digite o número total de páginas: 2
#                                      Título  \
# 0   Apartamento com 2 Quartos à Venda, 55m²
# 1                            Reserva Serena
# 2   Apartamento com 2 Quartos à Venda, 47m²
# 3   Apartamento com 3 Quartos à Venda, 80m²
# 4   Apartamento com 2 Quartos à Venda, 56m²
# ..                                      ...
# 67  Apartamento com 2 Quartos à Venda, 58m²
# 68  Apartamento com 3 Quartos à Venda, 73m²
# 69  Apartamento com 3 Quartos à Venda, 84m²
# 70  Apartamento com 2 Quartos à Venda, 45m²
# 71  Apartamento com 3 Quartos à Venda, 52m²
#
#                                              Endereço      Área      Quartos  \
# 0                       Jardim Miranda, Campinas - SP   55   m²  2   Quartos
# 1   Rodovia Governador Doutor Adhemar Pereira de B...  360   m²  --   Quarto
# 2    Rua Itaparica, 250 - Jardim Itayu, Campinas - SP   47   m²  2   Quartos
# 3   Rua Jacy Teixeira Camargo, 240 - Jardim do Lag...   80   m²  3   Quartos
# 4   Rua Manuel Francisco Monteiro, 368 - Parque In...   56   m²  2   Quartos
# ..                                                ...       ...          ...
# 67  Rua Doutor Cassiano Gonzaga, 672 - São Bernard...   58   m²  2   Quartos
# 68  Rua Alberto de Oliveira Maia, 65 - Conjunto Re...   73   m²  3   Quartos
# 69  Avenida Júlio Prestes, 741 - Taquaral, Campina...   84   m²  3   Quartos
# 70  Rua Visconde de Congonhas do Campo - Loteament...   45   m²  2   Quartos
# 71                        Parque Prado, Campinas - SP   52   m²  3   Quartos
#
#         Banheiros   Garagens                                    Preço  \
# 0    1   Banheiro   1   Vaga                               R$ 255.000
# 1   --   Banheiro  --   Vaga               A partir de     R$ 482.400
# 2    1   Banheiro   1   Vaga                               R$ 170.000
# 3   2   Banheiros  2   Vagas  R$ 426.000      Preço abaixo do mercado
# 4   2   Banheiros  2   Vagas                               R$ 420.000
# ..            ...        ...                                      ...
# 67   1   Banheiro   1   Vaga                               R$ 260.000
# 68   1   Banheiro   1   Vaga                               R$ 250.000
# 69  2   Banheiros   1   Vaga                               R$ 365.000
# 70   1   Banheiro   1   Vaga                               R$ 160.000
# 71   1   Banheiro   1   Vaga                               R$ 270.000
#
#    Condomínio
# 0      R$ 335
# 1        None
# 2      R$ 350
# 3      R$ 730
# 4      R$ 400
# ..        ...
# 67     R$ 478
# 68     R$ 308
# 69     R$ 800
# 70     R$ 330
# 71     R$ 280
#
# [72 rows x 8 columns]

# %%
import time

# URL da página a ser acessada
url = 'https://www.vivareal.com.br/venda/sp/campinas/apartamento_residencial/'

# Input do número total de páginas
num_paginas = int(input("Digite o número total de páginas: "))

# Lista vazia para armazenar os dados dos anúncios
data = []

# Loop pelas páginas para extrair as informações dos anúncios
for i in range(1, num_paginas + 1):
    # URL da página atual
    url_atual = url + f'?pagina={i}'

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

    response = requests.get(url_atual, headers=headers)

    # Aguardar 2 segundos antes de realizar a próxima requisição
    time.sleep(2)

    soup = BeautifulSoup(response.text, 'html.parser')

    primeiro_anuncio = soup.find('article', {'class': 'property-card__container js-property-card'})

    ul_comodidades = primeiro_anuncio.find('ul', {'class': 'property-card__amenities'})

    if ul_comodidades:
        comodidades = [comodidade.get('title') for comodidade in ul_comodidades.find_all('li')]
        print(comodidades)
    else:
        print('Comodidades não encontradas')

    anuncios = soup.find_all('article', {'class': 'property-card__container js-property-card'})
    comodidades_unicas = set()

    # Obter todas as comodidades presentes nos anúncios
    for anuncio in anuncios:
        ul_comodidades = anuncio.find('ul', {'class': 'property-card__amenities'})
        if ul_comodidades:
            comodidades = [comodidade.get('title') for comodidade in ul_comodidades.find_all('li')]
            comodidades_unicas.update(comodidades)

    # Criar DataFrame
    df_amenities = pd.DataFrame(columns=list(comodidades_unicas))

    # Preencher DataFrame com presença/ausência de cada comodidade em cada anúncio
    for i, anuncio in enumerate(anuncios):
        ul_comodidades = anuncio.find('ul', {'class': 'property-card__amenities'})
        if ul_comodidades:
            comodidades = {comodidade.get('title'): True for comodidade in ul_comodidades.find_all('li')}
        else:
            comodidades = {}
        df_amenities.loc[i] = {comodidade: comodidades.get(comodidade, False) for comodidade in comodidades_unicas}

    print(df_amenities)
# Out:
# Digite o número total de páginas: 2
# Comodidades não encontradas
#     Garagem  Piscina  Academia  Lavanderia  Varanda gourmet  Aceita animais  \
# 0     False    False     False       False            False           False
# 1     False    False     False       False            False           False
# 2     False    False     False       False            False           False
# 3     False    False     False       False            False           False
# 4      True     True     False       False            False           False
# 5     False    False     False       False            False           False
# 6     False    False     False       False            False           False
# 7     False     True      True       False            False            True
# 8     False    False     False       False            False           False
# 9     False     True      True       False            False           False
# 10     True     True     False       False            False           False
# 11    False    False     False       False            False           False
# 12     True    False      True       False            False           False
# 13    False    False     False       False            False           False
# 14    False    False     False       False            False           False
# 15    False    False     False       False            False           False
# 16    False    False     False       False             True           False
# 17    False    False      True       False            False           False
# 18    False    False     False       False            False           False
# 19    False    False     False       False            False           False
# 20    False    False     False       False            False           False
# 21     True    False      True       False            False           False
# 22    False     True     False       False            False           False
# 23    False    False     False       False             True           False
# 24    False    False     False       False            False           False
# 25    False    False     False       False            False           False
# 26    False    False     False       False            False           False
# 27    False    False     False       False            False           False
# 28    False    False     False       False            False           False
# 29    False    False     False       False            False           False
# 30    False    False     False       False            False           False
# 31    False     True      True       False            False           False
# 32    False     True     False       False            False           False
# 33     True    False     False       False            False           False
# 34    False    False     False       False            False           False
# 35     True    False     False        True            False           False
#
#      None  Área de serviço  Condomínio fechado  Cozinha  Churrasqueira  \
# 0   False            False               False    False          False
# 1   False            False               False    False          False
# 2   False            False               False    False          False
# 3   False            False               False    False          False
# 4   False            False               False    False          False
# 5   False            False               False    False          False
# 6   False             True               False    False          False
# 7    True            False               False    False           True
# 8   False            False               False    False          False
# 9    True            False                True    False           True
# 10   True            False               False     True          False
# 11  False            False               False    False          False
# 12   True            False               False     True           True
# 13  False            False               False    False          False
# 14  False            False               False    False          False
# 15  False            False               False    False          False
# 16  False            False               False    False           True
# 17  False            False               False    False          False
# 18  False            False               False    False          False
# 19  False            False               False    False          False
# 20  False            False               False    False          False
# 21   True            False               False    False           True
# 22  False            False               False    False          False
# 23   True             True               False    False           True
# 24  False            False               False    False          False
# 25  False            False               False    False          False
# 26  False            False               False    False          False
# 27  False             True                True     True          False
# 28  False            False               False    False          False
# 29  False            False               False    False          False
# 30   True             True                True     True           True
# 31   True            False               False    False           True
# 32   True            False                True    False           True
# 33  False            False               False    False          False
# 34  False             True                True     True          False
# 35  False            False               False    False          False
#
#     Piscina para adulto  Elevador  Varanda  Interfone  Playground  Escritório
# 0                 False     False    False      False       False       False
# 1                 False     False    False      False       False       False
# 2                 False     False    False      False       False       False
# 3                 False     False    False      False       False       False
# 4                  True     False    False       True       False       False
# 5                 False     False    False      False       False       False
# 6                 False     False    False       True       False       False
# 7                 False      True    False      False       False       False
# 8                 False     False    False      False       False       False
# 9                 False      True    False      False       False       False
# 10                False      True     True      False       False       False
# 11                False      True    False       True       False       False
# 12                False     False    False      False        True       False
# 13                False     False     True      False       False       False
# 14                False     False    False      False       False       False
# 15                False     False    False      False       False       False
# 16                False      True    False      False        True       False
# 17                False     False    False      False       False       False
# 18                False     False    False      False       False       False
# 19                False     False    False      False       False       False
# 20                False     False    False      False       False       False
# 21                False      True    False      False        True       False
# 22                 True     False     True       True        True       False
# 23                False      True     True      False       False       False
# 24                False     False    False      False       False       False
# 25                False     False     True      False       False       False
# 26                False     False    False      False       False       False
# 27                False     False    False       True       False       False
# 28                False     False     True      False       False       False
# 29                False     False    False      False       False       False
# 30                False     False    False       True       False       False
# 31                False      True     True      False       False       False
# 32                False      True     True      False       False       False
# 33                False     False    False       True       False       False
# 34                False     False    False      False       False        True
# 35                False     False    False      False       False       False
# ['Elevador', 'Garagem', 'Interfone', 'Cozinha']
#     Garagem  Lavanderia  Jardim  Mobiliado  Condomínio fechado  Cozinha  \
# 0      True       False   False      False               False     True
# 1     False       False   False      False               False    False
# 2     False       False   False      False               False    False
# 3     False       False   False      False               False    False
# 4     False        True   False       True               False    False
# 5      True       False   False      False               False     True
# 6     False       False   False      False               False    False
# 7      True       False   False      False               False    False
# 8     False       False   False      False               False    False
# 9     False       False   False      False               False    False
# 10    False       False   False      False               False    False
# 11    False       False   False      False               False    False
# 12    False       False   False      False               False    False
# 13    False       False   False      False               False    False
# 14    False       False   False      False               False    False
# 15    False       False   False      False               False    False
# 16    False       False   False      False               False    False
# 17    False       False   False      False               False    False
# 18    False       False   False      False               False    False
# 19    False       False   False      False               False    False
# 20     True       False   False      False               False    False
# 21    False       False   False      False               False    False
# 22    False       False   False      False               False    False
# 23    False       False   False      False               False    False
# 24    False       False   False      False                True     True
# 25    False       False   False      False               False    False
# 26    False       False   False      False                True     True
# 27    False       False   False      False               False    False
# 28    False       False   False      False               False    False
# 29    False       False   False      False                True    False
# 30    False       False   False      False                True     True
# 31     True        True   False      False               False    False
# 32     True       False   False      False               False     True
# 33    False       False   False      False                True    False
# 34    False       False    True      False               False    False
# 35    False       False   False      False               False    False
#
#     Churrasqueira  Playground  Portão eletrônico  Academia  ...  Escritório  \
# 0           False       False              False     False  ...       False
# 1           False       False              False     False  ...       False
# 2           False       False              False     False  ...       False
# 3            True       False              False      True  ...       False
# 4           False       False              False     False  ...       False
# 5           False       False              False     False  ...       False
# 6           False       False              False     False  ...       False
# 7           False       False              False     False  ...       False
# 8           False       False              False     False  ...       False
# 9            True       False              False     False  ...       False
# 10          False       False              False     False  ...       False
# 11          False       False              False     False  ...       False
# 12          False       False              False     False  ...       False
# 13          False       False              False     False  ...       False
# 14           True        True              False     False  ...       False
# 15          False       False              False     False  ...       False
# 16          False       False              False      True  ...       False
# 17          False       False              False     False  ...       False
# 18          False       False              False     False  ...       False
# 19          False       False              False     False  ...       False
# 20           True        True              False      True  ...       False
# 21          False        True              False     False  ...       False
# 22          False       False              False     False  ...       False
# 23          False       False              False     False  ...       False
# 24          False       False              False     False  ...       False
# 25          False       False              False     False  ...       False
# 26           True       False              False     False  ...       False
# 27           True       False              False      True  ...       False
# 28          False       False              False     False  ...       False
# 29           True       False              False     False  ...       False
# 30          False       False              False     False  ...        True
# 31          False       False              False     False  ...       False
# 32          False        True              False     False  ...       False
# 33          False       False               True     False  ...       False
# 34           True        True              False      True  ...       False
# 35          False       False              False     False  ...       False
#
#     Portaria 24h  Elevador  Piscina para adulto  Varanda  Piscina  \
# 0          False      True                False    False    False
# 1          False     False                False    False    False
# 2          False     False                False    False    False
# 3          False      True                False    False     True
# 4          False     False                False     True    False
# 5          False      True                False     True     True
# 6          False      True                False    False    False
# 7          False     False                False    False     True
# 8          False     False                False    False    False
# 9          False      True                False     True     True
# 10         False     False                False     True    False
# 11         False     False                False    False    False
# 12         False     False                False    False    False
# 13         False     False                False    False    False
# 14         False      True                False    False    False
# 15         False     False                False    False    False
# 16         False     False                False    False    False
# 17         False     False                False    False    False
# 18         False     False                False    False    False
# 19         False     False                False    False    False
# 20         False      True                False    False    False
# 21         False     False                 True     True     True
# 22         False     False                False    False    False
# 23         False     False                False     True    False
# 24         False     False                False    False    False
# 25         False     False                False     True    False
# 26         False     False                False    False    False
# 27         False      True                False     True     True
# 28         False     False                False    False    False
# 29         False      True                False     True     True
# 30         False     False                False    False    False
# 31         False     False                False    False    False
# 32         False     False                False    False    False
# 33          True     False                False    False    False
# 34         False     False                False    False    False
# 35         False     False                False    False    False
#
#     Espaço gourmet   None  Interfone  Aceita animais
# 0            False  False       True           False
# 1            False  False      False           False
# 2            False  False      False           False
# 3            False   True      False            True
# 4            False  False      False           False
# 5            False   True      False           False
# 6            False  False       True           False
# 7            False  False      False           False
# 8            False  False      False           False
# 9            False   True      False           False
# 10           False  False      False           False
# 11           False  False      False           False
# 12           False  False      False           False
# 13           False  False      False           False
# 14           False  False      False           False
# 15           False  False      False           False
# 16           False  False      False           False
# 17           False  False      False           False
# 18           False  False      False           False
# 19           False  False      False           False
# 20           False   True      False           False
# 21           False  False       True           False
# 22           False  False      False           False
# 23           False  False      False           False
# 24           False  False       True           False
# 25           False  False      False           False
# 26           False   True       True           False
# 27           False   True      False           False
# 28           False  False      False           False
# 29           False   True      False           False
# 30           False  False      False           False
# 31           False  False      False           False
# 32           False  False      False           False
# 33           False  False      False           False
# 34            True   True      False           False
# 35           False  False      False           False
#
# [36 rows x 22 columns]

# %%
df_final= pd.concat((df,df_amenities), axis=1)

display(df_final)
# Out:
# C:\Users\PEDRO\anaconda3\lib\site-packages\IPython\lib\pretty.py:700: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# C:\Users\PEDRO\anaconda3\lib\site-packages\IPython\core\formatters.py:345: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#                                       Título  \
# 0    Apartamento com 3 Quartos à Venda, 56m²
# 1                             Reserva Serena
# 2    Apartamento com 3 Quartos à Venda, 70m²
# 3    Apartamento com 2 Quartos à Venda, 55m²
# 4    Apartamento com 2 Quartos à Venda, 47m²
# ..                                       ...
# 283  Apartamento com 2 Quartos à Venda, 48m²
# 284  Apartamento com 3 Quartos à Venda, 67m²
# 285  Apartamento com 2 Quartos à Venda, 56m²
# 286  Apartamento com 2 Quartos à Venda, 52m²
# 287  Apartamento com 3 Quartos à Venda, 70m²
#
#                                               Endereço      Área      Quartos  \
# 0    Rua Lucindo Silva, 299 - Parque Fazendinha, Ca...   56   m²  3   Quartos
# 1    Rodovia Governador Doutor Adhemar Pereira de B...  360   m²  --   Quarto
# 2    Rua João Felipe Xavier da Silva, 25 - São Bern...   70   m²  3   Quartos
# 3                        Jardim Miranda, Campinas - SP   55   m²  2   Quartos
# 4     Rua Itaparica, 250 - Jardim Itayu, Campinas - SP   47   m²  2   Quartos
# ..                                                 ...       ...          ...
# 283  Avenida São José dos Campos, 150 - Jardim Nova...   48   m²  2   Quartos
# 284  Avenida João Batista Morato do Canto, 1653 - V...   67   m²  3   Quartos
# 285  Rua Engenheiro Augusto de Figueiredo, 357 - Vi...   56   m²  2   Quartos
# 286  Rua Engenheiro Augusto de Figueiredo, 357 - Sw...   52   m²  2   Quartos
# 287                   Parque Fazendinha, Campinas - SP   70   m²  3   Quartos
#
#          Banheiros   Garagens                                    Preço  \
# 0     1   Banheiro   1   Vaga  R$ 265.000      Preço abaixo do mercado
# 1    --   Banheiro  --   Vaga               A partir de     R$ 482.400
# 2    2   Banheiros   1   Vaga  R$ 250.000      Preço abaixo do mercado
# 3     1   Banheiro   1   Vaga                               R$ 255.000
# 4     1   Banheiro   1   Vaga                               R$ 170.000
# ..             ...        ...                                      ...
# 283  2   Banheiros   1   Vaga                               R$ 253.000
# 284  2   Banheiros   1   Vaga                               R$ 400.000
# 285   1   Banheiro   1   Vaga                               R$ 410.000
# 286   1   Banheiro   1   Vaga                               R$ 345.000
# 287  2   Banheiros  2   Vagas                               R$ 320.000
#
#     Condomínio Lavanderia Academia  ...   None Cozinha Elevador Garagem  \
# 0       R$ 320      False    False  ...  False   False    False   False
# 1         None      False    False  ...  False   False    False   False
# 2       R$ 500      False    False  ...  False   False    False   False
# 3       R$ 335      False    False  ...  False   False    False   False
# 4       R$ 350      False    False  ...   True   False    False   False
# ..         ...        ...      ...  ...    ...     ...      ...     ...
# 283     R$ 310        NaN      NaN  ...    NaN     NaN      NaN     NaN
# 284     R$ 640        NaN      NaN  ...    NaN     NaN      NaN     NaN
# 285     R$ 303        NaN      NaN  ...    NaN     NaN      NaN     NaN
# 286     R$ 332        NaN      NaN  ...    NaN     NaN      NaN     NaN
# 287     R$ 420        NaN      NaN  ...    NaN     NaN      NaN     NaN
#
#     Perto de vias de acesso Perto de shopping Perto de escolas Playground  \
# 0                     False             False            False      False
# 1                     False             False            False      False
# 2                     False             False            False      False
# 3                     False             False            False      False
# 4                      True              True             True      False
# ..                      ...               ...              ...        ...
# 283                     NaN               NaN              NaN        NaN
# 284                     NaN               NaN              NaN        NaN
# 285                     NaN               NaN              NaN        NaN
# 286                     NaN               NaN              NaN        NaN
# 287                     NaN               NaN              NaN        NaN
#
#     Segurança 24h Espaço gourmet
# 0           False          False
# 1           False          False
# 2           False          False
# 3           False          False
# 4           False          False
# ..            ...            ...
# 283           NaN            NaN
# 284           NaN            NaN
# 285           NaN            NaN
# 286           NaN            NaN
# 287           NaN            NaN
#
# [288 rows x 33 columns]

# %%
df_final.to_excel('consolidado pag8.xlsx')
