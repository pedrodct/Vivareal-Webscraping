# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL da primeira página
url = 'https://www.vivareal.com.br/venda/sp/campinas/apartamento_residencial/'

# Input do número total de páginas
num_paginas = int(input("Digite o número total de páginas: "))

# Lista vazia para armazenar os dados dos anúncios
data = []

# Loop pelas páginas para extrair as informações dos anúncios
for i in range(1, num_paginas + 1):
    # URL da página atual
    url_atual = url + f'?pagina={i}'

    # Realiza a requisição HTTP
    response = requests.get(url_atual)

    # Verifica se a requisição foi bem sucedida
    if response.status_code == 200:
        # Cria o objeto BeautifulSoup para fazer o parsing do HTML
        soup = BeautifulSoup(response.content, 'html.parser')

        # Busca pelos anúncios presentes na página
        anuncios = soup.find_all('article', {'class': 'property-card__container'})

        # Loop pelos anúncios para extrair as informações desejadas
        for anuncio in anuncios:
            titulo = anuncio.find('span', {'class': 'property-card__title'}).text.strip()
            endereco = anuncio.find('span', {'class': 'property-card__address'}).text.strip()
            area = anuncio.find('li', {'class': 'property-card__detail-area'}).text.strip()
            quartos = anuncio.find('li', {'class': 'property-card__detail-room'}).text.strip()
            banheiros = anuncio.find('li', {'class': 'property-card__detail-bathroom'}).text.strip()
            garagens = anuncio.find('li', {'class': 'property-card__detail-garage'}).text.strip()
            preco = anuncio.find('div', {'class': 'property-card__price'}).text.strip()
            condominio_tag = anuncio.find('span', {'class': 'property-card__price-details--condo'})
            condominio = condominio_tag.text.strip() if condominio_tag else None

            # Adiciona os dados à lista
            data.append([titulo, endereco, area, quartos, banheiros, garagens, preco, condominio])
    else:
        print(f'Não foi possível obter os dados da página {i}.')

# Cria um dataframe com os dados
df = pd.DataFrame(data, columns=['Título', 'Endereço', 'Área', 'Quartos', 'Banheiros', 'Garagens', 'Preço', 'Condomínio'])

# Exibe o dataframe
display(df)
# Out:
# Digite o número total de páginas: 2
#                                       Título  \
# 0    Apartamento com 3 Quartos à Venda, 74m²
# 1                             Reserva Serena
# 2   Apartamento com 3 Quartos à Venda, 108m²
# 3    Apartamento com 3 Quartos à Venda, 55m²
# 4    Apartamento com 2 Quartos à Venda, 47m²
# ..                                       ...
# 67  Apartamento com 2 Quartos à Venda, 112m²
# 68   Apartamento com 3 Quartos à Venda, 78m²
# 69   Apartamento com 2 Quartos à Venda, 51m²
# 70   Apartamento com 3 Quartos à Venda, 60m²
# 71  Apartamento com 2 Quartos à Venda, 121m²
#
#                                              Endereço      Área      Quartos  \
# 0   Rua Lauro Vannucci, 997 - Mansões Santo Antôni...   74   m²  3   Quartos
# 1   Rodovia Governador Doutor Adhemar Pereira de B...  360   m²  --   Quarto
# 2   Rua João Lopes Vieira, 81 - Loteamento Residen...  108   m²  3   Quartos
# 3                    Jardim Dom Vieira, Campinas - SP   55   m²  3   Quartos
# 4   Rua Djalma Inácio Furtado, 72 - Parque das Cac...   47   m²  2   Quartos
# ..                                                ...       ...          ...
# 67  Rua Ferreira Penteado, 535 - Centro, Campinas ...  112   m²  2   Quartos
# 68  Rua Sargento Luís de Morais, 605 - Jardim São ...   78   m²  3   Quartos
# 69  Rua Ézio Wagner da Silva, 114-0 - Residencial ...   51   m²  2   Quartos
# 70                     Vila João Jorge, Campinas - SP   60   m²  3   Quartos
# 71  Rua Maria Mercedes Etter Von Zuben - Jardim An...  121   m²  2   Quartos
#
#         Banheiros   Garagens                       Preço Condomínio
# 0   3   Banheiros  2   Vagas                  R$ 671.723       None
# 1   --   Banheiro  --   Vaga  A partir de     R$ 482.400       None
# 2   4   Banheiros  2   Vagas                R$ 1.200.000       None
# 3    1   Banheiro   1   Vaga                  R$ 270.000       None
# 4    1   Banheiro   1   Vaga                  R$ 210.000       None
# ..            ...        ...                         ...        ...
# 67  2   Banheiros  --   Vaga                  R$ 420.000       None
# 68  2   Banheiros  2   Vagas                  R$ 630.000       None
# 69   1   Banheiro   1   Vaga                  R$ 297.900       None
# 70  2   Banheiros   1   Vaga                  R$ 300.000       None
# 71  3   Banheiros  2   Vagas                  R$ 485.000       None
#
# [72 rows x 8 columns]

# %%
# URL da primeira página
url = 'https://www.vivareal.com.br/venda/sp/campinas/apartamento_residencial/'

# Input do número total de páginas
num_paginas = int(input("Digite o número total de páginas: "))

# Lista vazia para armazenar os dados dos anúncios
data = []

# Loop pelas páginas para extrair as informações dos anúncios
for i in range(1, num_paginas + 1):
    # URL da página atual
    url_atual = url + f'?pagina={i}'

    # Realiza a requisição HTTP
    response = requests.get(url_atual)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Encontra todos os anúncios na página
    anuncios = soup.find_all('article', {'class': 'property-card__container js-property-card'})
    
    # Extrai as amenidades dos anúncios
    comodidades_unicas = set()
    for anuncio in anuncios:
        ul_comodidades = anuncio.find('ul', {'class': 'property-card__amenities'})
        if ul_comodidades:
            comodidades = [comodidade.get('title') for comodidade in ul_comodidades.find_all('li')]
            comodidades_unicas.update(comodidades)

    # Cria o DataFrame
    df_amenities = pd.DataFrame(columns=list(comodidades_unicas))

    # Preenche o DataFrame com presença/ausência de cada comodidade em cada anúncio
    for j, anuncio in enumerate(anuncios):
        ul_comodidades = anuncio.find('ul', {'class': 'property-card__amenities'})
        if ul_comodidades:
            comodidades = {comodidade.get('title'): True for comodidade in ul_comodidades.find_all('li')}
        else:
            comodidades = {}
        df_amenities.loc[j] = {comodidade: comodidades.get(comodidade, False) for comodidade in comodidades_unicas}

    # Adiciona o DataFrame de amenidades à lista de dados
    data.append(df_amenities)

# Concatena os DataFrames de cada página
df_1 = pd.concat(data, ignore_index=True)

print(df_1)
# Out:
# Digite o número total de páginas: 2
#     Piscina  Espaço gourmet  Varanda gourmet  Churrasqueira  Interfone  \
# 0      True           False            False           True      False
# 1     False           False            False          False      False
# 2     False           False            False          False      False
# 3     False           False            False           True      False
# 4     False           False            False          False      False
# ..      ...             ...              ...            ...        ...
# 67     True           False            False           True      False
# 68    False           False            False          False      False
# 69     True           False            False           True       True
# 70    False           False            False           True      False
# 71    False           False            False           True      False
#
#     Academia  Salão de festas  Varanda  Elevador   None  ...  Área de serviço  \
# 0       True            False    False      True   True  ...            False
# 1      False            False    False     False  False  ...            False
# 2      False            False    False     False  False  ...            False
# 3       True            False    False     False  False  ...            False
# 4      False            False    False     False  False  ...            False
# ..       ...              ...      ...       ...    ...  ...              ...
# 67     False            False    False     False   True  ...              NaN
# 68     False            False    False     False  False  ...              NaN
# 69     False            False    False      True   True  ...              NaN
# 70     False             True     True     False   True  ...              NaN
# 71      True            False     True     False   True  ...              NaN
#
#     Piscina para adulto  Lavanderia  Quadra poliesportiva  Playground  \
# 0                 False       False                 False       False
# 1                 False       False                 False       False
# 2                 False       False                 False       False
# 3                 False       False                 False       False
# 4                 False       False                 False       False
# ..                  ...         ...                   ...         ...
# 67                False        True                   NaN       False
# 68                False       False                   NaN       False
# 69                False       False                   NaN        True
# 70                False       False                   NaN        True
# 71                False       False                   NaN        True
#
#     Quintal Jardim  Perto de hospitais  Mobiliado Perto de escolas
# 0       NaN    NaN                 NaN        NaN              NaN
# 1       NaN    NaN                 NaN        NaN              NaN
# 2       NaN    NaN                 NaN        NaN              NaN
# 3       NaN    NaN                 NaN        NaN              NaN
# 4       NaN    NaN                 NaN        NaN              NaN
# ..      ...    ...                 ...        ...              ...
# 67    False  False               False      False            False
# 68    False  False               False      False            False
# 69    False  False               False      False            False
# 70    False  False               False      False            False
# 71    False  False               False      False            False
#
# [72 rows x 26 columns]
# C:\Users\PEDRO\AppData\Local\Temp\ipykernel_13932\3067766355.py:48: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   print(df_1)

# %%
df_final= pd.concat((df,df_1), axis=1)

display(df_final)
# Out:
# C:\Users\PEDRO\anaconda3\lib\site-packages\IPython\lib\pretty.py:700: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# C:\Users\PEDRO\anaconda3\lib\site-packages\IPython\core\formatters.py:345: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   return method()
#                                       Título  \
# 0    Apartamento com 3 Quartos à Venda, 74m²
# 1                             Reserva Serena
# 2   Apartamento com 3 Quartos à Venda, 108m²
# 3    Apartamento com 3 Quartos à Venda, 55m²
# 4    Apartamento com 2 Quartos à Venda, 47m²
# ..                                       ...
# 67  Apartamento com 2 Quartos à Venda, 112m²
# 68   Apartamento com 3 Quartos à Venda, 78m²
# 69   Apartamento com 2 Quartos à Venda, 51m²
# 70   Apartamento com 3 Quartos à Venda, 60m²
# 71  Apartamento com 2 Quartos à Venda, 121m²
#
#                                              Endereço      Área      Quartos  \
# 0   Rua Lauro Vannucci, 997 - Mansões Santo Antôni...   74   m²  3   Quartos
# 1   Rodovia Governador Doutor Adhemar Pereira de B...  360   m²  --   Quarto
# 2   Rua João Lopes Vieira, 81 - Loteamento Residen...  108   m²  3   Quartos
# 3                    Jardim Dom Vieira, Campinas - SP   55   m²  3   Quartos
# 4   Rua Djalma Inácio Furtado, 72 - Parque das Cac...   47   m²  2   Quartos
# ..                                                ...       ...          ...
# 67  Rua Ferreira Penteado, 535 - Centro, Campinas ...  112   m²  2   Quartos
# 68  Rua Sargento Luís de Morais, 605 - Jardim São ...   78   m²  3   Quartos
# 69  Rua Ézio Wagner da Silva, 114-0 - Residencial ...   51   m²  2   Quartos
# 70                     Vila João Jorge, Campinas - SP   60   m²  3   Quartos
# 71  Rua Maria Mercedes Etter Von Zuben - Jardim An...  121   m²  2   Quartos
#
#         Banheiros   Garagens                       Preço Condomínio  Piscina  \
# 0   3   Banheiros  2   Vagas                  R$ 671.723       None     True
# 1   --   Banheiro  --   Vaga  A partir de     R$ 482.400       None    False
# 2   4   Banheiros  2   Vagas                R$ 1.200.000       None    False
# 3    1   Banheiro   1   Vaga                  R$ 270.000       None    False
# 4    1   Banheiro   1   Vaga                  R$ 210.000       None    False
# ..            ...        ...                         ...        ...      ...
# 67  2   Banheiros  --   Vaga                  R$ 420.000       None     True
# 68  2   Banheiros  2   Vagas                  R$ 630.000       None    False
# 69   1   Banheiro   1   Vaga                  R$ 297.900       None     True
# 70  2   Banheiros   1   Vaga                  R$ 300.000       None    False
# 71  3   Banheiros  2   Vagas                  R$ 485.000       None    False
#
#     Espaço gourmet  ...  Área de serviço  Piscina para adulto  Lavanderia  \
# 0            False  ...            False                False       False
# 1            False  ...            False                False       False
# 2            False  ...            False                False       False
# 3            False  ...            False                False       False
# 4            False  ...            False                False       False
# ..             ...  ...              ...                  ...         ...
# 67           False  ...              NaN                False        True
# 68           False  ...              NaN                False       False
# 69           False  ...              NaN                False       False
# 70           False  ...              NaN                False       False
# 71           False  ...              NaN                False       False
#
#     Quadra poliesportiva  Playground  Quintal  Jardim  Perto de hospitais  \
# 0                  False       False      NaN     NaN                 NaN
# 1                  False       False      NaN     NaN                 NaN
# 2                  False       False      NaN     NaN                 NaN
# 3                  False       False      NaN     NaN                 NaN
# 4                  False       False      NaN     NaN                 NaN
# ..                   ...         ...      ...     ...                 ...
# 67                   NaN       False    False   False               False
# 68                   NaN       False    False   False               False
# 69                   NaN        True    False   False               False
# 70                   NaN        True    False   False               False
# 71                   NaN        True    False   False               False
#
#     Mobiliado  Perto de escolas
# 0         NaN               NaN
# 1         NaN               NaN
# 2         NaN               NaN
# 3         NaN               NaN
# 4         NaN               NaN
# ..        ...               ...
# 67      False             False
# 68      False             False
# 69      False             False
# 70      False             False
# 71      False             False
#
# [72 rows x 34 columns]
