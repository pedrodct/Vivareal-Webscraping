# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.vivareal.com.br/venda/sp/campinas/apartamento_residencial/'

# Input do número total de páginas
num_paginas = int(input("Digite o número total de páginas: "))

# Lista vazia para armazenar os dados dos anúncios
data = []

# Loop pelas páginas para extrair as informações dos anúncios
for i in range(1, num_paginas + 1):
    # URL da página atual
    url_atual = url + f'?pagina={i}'

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }

    response = requests.get(url_atual, headers=headers)

    soup = BeautifulSoup(response.text, 'html.parser')

    anuncios = soup.find_all('article', {'class': 'property-card__container js-property-card'})

    for anuncio in anuncios:
        # Extrair informações do anúncio
        endereco = anuncio.find('span', {'class': 'property-card__address'}).text.strip()
        area = anuncio.find('span', {'class': 'property-card__detail-area'}).text.strip()
        quartos = anuncio.find('li', {'class': 'property-card__detail-room'}).span.text.strip()
        banheiros = anuncio.find('li', {'class': 'property-card__detail-bathroom'}).span.text.strip()
        vagas = anuncio.find('li', {'class': 'property-card__detail-garage'}).span.text.strip()
        valor = anuncio.find('div', {'class': 'property-card__price'}).text.strip()

        # Extrair preço do condomínio
        condominio_tag = anuncio.find('div', {'class': 'property-card__price-details--condo'})
        if condominio_tag:
            condominio = condominio_tag.text.strip()
        else:
            condominio = '0'

        # Extrair comodidades do anúncio
        ul_comodidades = anuncio.find('ul', {'class': 'property-card__amenities'})
        if ul_comodidades:
            comodidades = [comodidade.get('title') for comodidade in ul_comodidades.find_all('li')]
        else:
            comodidades = [False] * len(df_amenities.columns) # Retorna lista com False caso não encontre comodidades

        # Salvar informações em um dicionário
        anuncio_dict = {
            'Endereço': endereco,
            'Área': area,
            'Quartos': quartos,
            'Banheiros': banheiros,
            'Vagas': vagas,
            'Valor': valor,
            'Condomínio': condominio
        }
        anuncio_dict.update({comodidade: True for comodidade in comodidades})
        data.append(anuncio_dict)

# Criar DataFrame
df = pd.DataFrame(data)

# Reordenar as colunas do DataFrame
colunas = ['Endereço', 'Área', 'Quartos', 'Banheiros', 'Vagas', 'Valor', 'Condomínio']
colunas += [coluna for coluna in df.columns if coluna not in colunas]
df = df[colunas]

# Salvar DataFrame em um arquivo Excel
df.to_excel('anuncios.xlsx', index=False)

print(df)
# Out:
# Digite o número total de páginas: 1
#                                              Endereço   Área Quartos  \
# 0   Rua Jacy Teixeira Camargo, 240 - Jardim do Lag...     80       3
# 1   Rodovia Governador Doutor Adhemar Pereira de B...    360      --
# 2   Rua Campos do Jordão, 449 - Fundação da Casa P...     54       2
# 3   Rua Pedro Vieira da Silva, 595 - Jardim Santa ...     77       3
# 4      Rua João Iamarino, 3 - Taquaral, Campinas - SP     50       2
# 5   Rua Ministro Oscar Saraiva, 40 - Jardim das Pa...    116       3
# 6   Avenida Nélsia Vannucci, 105 - Loteamento Chac...     75       3
# 7   Avenida Padre Guilherme Ary - Vila Satúrnia, C...     51       2
# 8    Rua Álvares Machado, 248 - Centro, Campinas - SP     55       2
# 9                             Taquaral, Campinas - SP     61       2
# 10  Rua Baronesa Geraldo de Resende, 534 - Taquara...    240       3
# 11  Rua Pinheiros, 200 - Vila Industrial, Campinas...     68       3
# 12      Jardim Myrian Moreira da Costa, Campinas - SP     50       2
# 13  Rua Luciana Von Zuben Corvini, 64 - Parque das...     47       2
# 14  Rua Maria Mercedes Etter Von Zuben, 151 - Jard...     51       2
# 15  Rua 8, 26 - Residencial Fazenda Lagoa, Campina...  35-36       2
# 16  Loteamento Residencial Parque dos Cantos, Camp...     45       2
# 17  Rua Serra da Mantiqueira, 169 - Jardim Novo Sã...     70       2
# 18  Avenida São José dos Campos, 3297 - Jardim Nov...     48       2
# 19  Avenida São José dos Campos, 3385 - Loteamento...     47       2
# 20                   Parque Fazendinha, Campinas - SP     70       3
# 21                    Jardim Paulicéia, Campinas - SP     56       2
# 22  Rua Pinheiros, 200 - Vila Industrial, Campinas...     68       3
# 23  Avenida Carlos de Araújo Gobbi, 220 - Vila São...     59       2
# 24  Avenida Washington Luís, 4300 - Vila Marieta, ...     58       3
# 25  Avenida Nélsia Vannucci, 105 - Loteamento Chac...     75       3
# 26  Rua Almirante Custódio José de Melo, 351 - Jar...     60       2
# 27  Avenida Engenheiro Antônio Francisco de Paula ...     43       2
# 28  Rua Caçapava, 358 - Vila Industrial, Campinas ...     64       2
# 29  Rua Álvaro Ribeiro, 86 - Ponte Preta, Campinas...     84       3
# 30                  Jardim Nova Europa, Campinas - SP     60       3
# 31  Rua Francisco Bueno Lacerda, 220 - Jardim Dom ...     58       2
# 32  Avenida Washington Luís, 4000 - Vila Marieta, ...     52       3
# 33  Rua Ministro Oscar Saraiva, 130 - Jardim das P...     75       3
# 34  Rua Djalma Inácio Furtado, 72 - Parque das Cac...     42       2
# 35                      Jardim do Lago, Campinas - SP     65       2
#
#    Banheiros Vagas                                    Valor  \
# 0          2     2  R$ 420.000      Preço abaixo do mercado
# 1         --    --               A partir de     R$ 482.400
# 2          2     1                               R$ 380.000
# 3          2     2                               R$ 495.000
# 4          1     1                               R$ 210.000
# 5          2     2  R$ 730.000      Preço abaixo do mercado
# 6          2     1                               R$ 535.000
# 7          1     1                               R$ 400.000
# 8          2     1                             Sob Consulta
# 9          2     1                               R$ 650.000
# 10         5     3                             R$ 1.850.000
# 11         1     2                               R$ 300.000
# 12         1     1                               R$ 270.000
# 13         1     1                               R$ 230.000
# 14         2     1                               R$ 270.000
# 15         1     1               A partir de     R$ 158.870
# 16         1     1                               R$ 240.000
# 17         2     2  R$ 290.000      Preço abaixo do mercado
# 18         1     1                               R$ 195.000
# 19         1     1                               R$ 225.000
# 20         2     2                               R$ 330.000
# 21         1     1                               R$ 199.900
# 22         1     1                               R$ 323.000
# 23         1     1                               R$ 239.000
# 24         1     1                               R$ 334.900
# 25         2     1                               R$ 520.000
# 26         1     1                               R$ 225.000
# 27         1     1                               R$ 240.000
# 28         2     1                               R$ 458.000
# 29         2     1                               R$ 450.000
# 30         2     1                               R$ 340.000
# 31         1     1                               R$ 290.000
# 32         1     1                               R$ 320.000
# 33         2     2                               R$ 560.000
# 34         1     1                               R$ 210.000
# 35         1     1                               R$ 220.000
#
#                 Condomínio Piscina Churrasqueira Elevador  ...  \
# 0     Condomínio:   R$ 729    True          True     True  ...
# 1                        0     NaN           NaN      NaN  ...
# 2     Condomínio:   R$ 450    True          True     True  ...
# 3     Condomínio:   R$ 650    True           NaN      NaN  ...
# 4     Condomínio:   R$ 390     NaN           NaN      NaN  ...
# 5     Condomínio:   R$ 995    True           NaN     True  ...
# 6     Condomínio:   R$ 605     NaN           NaN      NaN  ...
# 7     Condomínio:   R$ 450     NaN           NaN      NaN  ...
# 8                        0     NaN           NaN      NaN  ...
# 9     Condomínio:   R$ 560     NaN           NaN     True  ...
# 10  Condomínio:   R$ 1.500    True          True     True  ...
# 11    Condomínio:   R$ 850     NaN           NaN     True  ...
# 12    Condomínio:   R$ 335     NaN           NaN     True  ...
# 13    Condomínio:   R$ 240     NaN          True      NaN  ...
# 14    Condomínio:   R$ 400     NaN          True      NaN  ...
# 15                       0     NaN           NaN      NaN  ...
# 16    Condomínio:   R$ 245     NaN           NaN      NaN  ...
# 17    Condomínio:   R$ 400     NaN           NaN      NaN  ...
# 18    Condomínio:   R$ 260     NaN          True      NaN  ...
# 19    Condomínio:   R$ 223     NaN          True      NaN  ...
# 20    Condomínio:   R$ 420    True           NaN      NaN  ...
# 21    Condomínio:   R$ 380     NaN           NaN      NaN  ...
# 22    Condomínio:   R$ 575     NaN           NaN     True  ...
# 23    Condomínio:   R$ 360     NaN           NaN      NaN  ...
# 24    Condomínio:   R$ 425     NaN           NaN      NaN  ...
# 25    Condomínio:   R$ 500    True          True     True  ...
# 26    Condomínio:   R$ 270     NaN           NaN      NaN  ...
# 27    Condomínio:   R$ 320     NaN          True      NaN  ...
# 28    Condomínio:   R$ 495    True          True      NaN  ...
# 29    Condomínio:   R$ 780     NaN           NaN      NaN  ...
# 30    Condomínio:   R$ 320    True           NaN      NaN  ...
# 31    Condomínio:   R$ 500     NaN          True      NaN  ...
# 32    Condomínio:   R$ 314     NaN           NaN      NaN  ...
# 33    Condomínio:   R$ 950    True          True     True  ...
# 34    Condomínio:   R$ 270     NaN          True      NaN  ...
# 35    Condomínio:   R$ 315     NaN           NaN      NaN  ...
#
#    Área de serviço Interfone Segurança 24h Salão de festas Playground  \
# 0              NaN       NaN           NaN             NaN        NaN
# 1              NaN       NaN           NaN             NaN        NaN
# 2              NaN       NaN           NaN             NaN        NaN
# 3              NaN       NaN           NaN             NaN        NaN
# 4              NaN       NaN           NaN             NaN        NaN
# 5              NaN       NaN           NaN             NaN        NaN
# 6              NaN       NaN           NaN             NaN        NaN
# 7              NaN       NaN           NaN             NaN        NaN
# 8              NaN       NaN           NaN             NaN        NaN
# 9              NaN       NaN           NaN             NaN        NaN
# 10             NaN       NaN           NaN             NaN        NaN
# 11            True       NaN           NaN             NaN        NaN
# 12             NaN      True           NaN             NaN        NaN
# 13             NaN       NaN          True            True        NaN
# 14             NaN       NaN           NaN             NaN       True
# 15             NaN       NaN           NaN             NaN        NaN
# 16             NaN       NaN           NaN             NaN        NaN
# 17             NaN       NaN           NaN             NaN        NaN
# 18             NaN       NaN           NaN            True        NaN
# 19             NaN       NaN           NaN             NaN        NaN
# 20             NaN       NaN           NaN             NaN        NaN
# 21             NaN       NaN           NaN             NaN        NaN
# 22             NaN       NaN           NaN             NaN        NaN
# 23            True       NaN           NaN            True       True
# 24             NaN       NaN           NaN             NaN        NaN
# 25             NaN       NaN           NaN             NaN        NaN
# 26             NaN       NaN           NaN             NaN        NaN
# 27             NaN       NaN           NaN             NaN        NaN
# 28             NaN       NaN           NaN             NaN        NaN
# 29             NaN       NaN           NaN             NaN        NaN
# 30             NaN       NaN           NaN             NaN        NaN
# 31             NaN       NaN           NaN             NaN        NaN
# 32             NaN       NaN           NaN             NaN        NaN
# 33             NaN       NaN           NaN             NaN        NaN
# 34             NaN       NaN           NaN             NaN        NaN
# 35             NaN       NaN           NaN             NaN        NaN
#
#    Salão de jogos Jardim Cozinha Espaço gourmet Varanda gourmet
# 0             NaN    NaN     NaN            NaN             NaN
# 1             NaN    NaN     NaN            NaN             NaN
# 2             NaN    NaN     NaN            NaN             NaN
# 3             NaN    NaN     NaN            NaN             NaN
# 4             NaN    NaN     NaN            NaN             NaN
# 5             NaN    NaN     NaN            NaN             NaN
# 6             NaN    NaN     NaN            NaN             NaN
# 7             NaN    NaN     NaN            NaN             NaN
# 8             NaN    NaN     NaN            NaN             NaN
# 9             NaN    NaN     NaN            NaN             NaN
# 10            NaN    NaN     NaN            NaN             NaN
# 11            NaN    NaN     NaN            NaN             NaN
# 12            NaN    NaN     NaN            NaN             NaN
# 13            NaN    NaN     NaN            NaN             NaN
# 14           True    NaN     NaN            NaN             NaN
# 15            NaN    NaN     NaN            NaN             NaN
# 16            NaN    NaN     NaN            NaN             NaN
# 17            NaN    NaN     NaN            NaN             NaN
# 18            NaN   True     NaN            NaN             NaN
# 19            NaN    NaN     NaN            NaN             NaN
# 20            NaN    NaN     NaN            NaN             NaN
# 21            NaN    NaN     NaN            NaN             NaN
# 22            NaN    NaN    True            NaN             NaN
# 23            NaN    NaN     NaN            NaN             NaN
# 24            NaN    NaN     NaN            NaN             NaN
# 25            NaN    NaN     NaN            NaN             NaN
# 26            NaN    NaN     NaN            NaN             NaN
# 27            NaN    NaN     NaN           True             NaN
# 28            NaN    NaN     NaN            NaN             NaN
# 29            NaN    NaN     NaN            NaN            True
# 30            NaN    NaN     NaN            NaN             NaN
# 31            NaN    NaN     NaN            NaN             NaN
# 32            NaN    NaN     NaN            NaN             NaN
# 33            NaN    NaN     NaN            NaN             NaN
# 34           True    NaN     NaN            NaN             NaN
# 35            NaN    NaN     NaN            NaN             NaN
#
# [36 rows x 34 columns]
